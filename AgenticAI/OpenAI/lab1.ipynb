# %%
from dotenv import load_dotenv
import os
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="TestAgent",instructions="You are a joke teller.", model="gpt-4o-mini")

# %%
with trace("Telling a joke"):
    response = await Runner.run(agent,"Tell me a joke about US")
    print(response.final_output)
# Out:
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-proj-********************************************************************************************************************************************************0jIA. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# Why did the scarecrow win an award in America?
#
# Because he was outstanding in his field!
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-proj-********************************************************************************************************************************************************0jIA. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }

# %% [markdown]
# # Now go and look at the trace
# ##https://platform.openai.com/traces
